# %%
import pandas as pd
CarPrice_df = pd.read_csv('CarPrice_Assignment.csv')
CarPrice_df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
CarPrice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
CarPrice_df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
pio.renderers.default = 'iframe'
from IPython.display import HTML
import numpy as np

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10,6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
fig = px.histogram(CarPrice_df, 
                   x='carlength', 
                   marginal='box', 
                   nbins=10, 
                   title='Distribution of Car Length')
fig.update_layout(bargap=0.01)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_87.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.histogram(CarPrice_df, 
                   x='enginesize', 
                   marginal='box',
                   nbins=15,
                   color_discrete_sequence=['red'], 
                   title='Size of Engine')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_88.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#Distribution of Car Prices
fig = px.histogram(CarPrice_df, 
                   x='price', 
                   marginal='box', 
                   color='enginesize', 
                   color_discrete_sequence=['red', 'blue'], 
                   title='Car Prices Ranges Distribution')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_89.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
px.histogram(CarPrice_df, x='price', color='drivewheel', title='Count of "Drive Wheel" to Price Range')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_90.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.scatter(CarPrice_df, 
                 x='enginesize', 
                 y='price', 
                 color='carlength', 
                 opacity=1, 
                 hover_data=['drivewheel'], 
                 title='Price vs Engine Size')
fig.update_traces(marker_size=5)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_91.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.strip(CarPrice_df, 
                 x='cylindernumber', 
                 y='price', 
                 color='carlength', 
                 #opacity=1, 
                 hover_data=['drivewheel'], 
                 title='Price vs Cylinders')
fig.update_traces(marker_size=5)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_92.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# It seems that Number of Cylinders and Engine Size is directly proportional to the increase in price of cars

# %% [markdown]
# Correlation

# %%
CarPrice_df.price.corr(CarPrice_df.enginesize)
# Out:
# 0.8741448025245118

# %%
CarPrice_df.price.corr(CarPrice_df.carlength)
# Out:
# 0.6829200156779623

# %%
#Manual Conversion of Cylinder: String to Numeric

Cylinder_Num = {'two': 2, 'three': 3, 'four': 4, 'five': 5, 'six': 6, 'eight': 8, 'twelve': 12}
Cylinder_Num = CarPrice_df.cylindernumber.map(Cylinder_Num)
CarPrice_df.price.corr(Cylinder_Num)
# Out:
# 0.7183049020002833

# %%
CarPrice_df.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
# %%time
sns.pairplot(CarPrice_df)
# Out:
# CPU times: user 15.8 s, sys: 247 ms, total: 16 s
# Wall time: 16.1 s

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(CarPrice_df.corr(), cmap='Blues', annot=True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Linear Regression using Single Feature

# %% [markdown]
# Now we know that engine size and curb weight are the most correlated factors, hence creating a DataFrame for it.

# %%
plt.title('Engine vs. Prices')
sns.scatterplot(data=CarPrice_df, x='enginesize', y='curbweight', alpha=0.7, s=15);

# %% [markdown]
# Linear Model \
# y = wx + b \
# y = price of car \
# price = wx + b

# %%
def estimate_price(enginesize, w, b):
    return w * enginesize + b

# %% [markdown]
# Lets guess the w and b are 10 and 20

# %%
w = 10
b = 20

# %%
enginesizes = CarPrice_df.enginesize
estimated_price = estimate_price(enginesizes, w, b)

# %%
plt.plot(enginesizes, estimated_price, 'r-o');
plt.xlabel('Engize Size');
plt.ylabel('Price');

# %%
target = CarPrice_df.price

plt.plot(enginesizes, estimated_price, 'r', alpha=0.9);
plt.scatter(enginesizes, target, s=8,alpha=0.8);
plt.xlabel('Engine Size');
plt.ylabel('Price')
plt.legend(['Estimate', 'Actual']);

# %% [markdown]
# Estimate isnt good enough and therefore needs further needs to evaluated with new values

# %%
def try_parameters(w, b):
    enginesizes = CarPrice_df.enginesize
    target = CarPrice_df.price
    
    estimated_price = estimate_price(enginesizes, w, b)
    
    plt.plot(enginesizes, estimated_price, 'r', alpha=0.9)
    plt.scatter(enginesizes, target, s=8,alpha=0.8)
    plt.xlabel('EngineSize')
    plt.ylabel('Price')
    plt.legend(['Estimate', 'Actual'])

# %%
try_parameters(115, 100)

# %% [markdown]
# Loss Cost Function
#
# 1. Difference between the predicted value and actual value
#
# 2. Average out the sum of the squared difference between predicted and actual values
#
# 3. RMSE can be calculated by taking the square root of above mentioned Mean Squared Errors (MSE) / L2 Loss. The effect of each error on RMSE is proportional to the size of the squared error. It represents the square root of the second sample moment of the deviation between predicted model values and actual values.
#
# More details:
#
# https://medium.com/analytics-vidhya/common-loss-functions-in-machine-learning-for-a-regression-model-27d2bbda9c93

# %%
import numpy as np

# %%
def rmse(targets, predictions):
    return np.sqrt(np.mean(np.square(targets - predictions)))

w = 115
b = 100

# %%
try_parameters(w, b)

# %%
targets = CarPrice_df['price']
predicted = estimate_price(CarPrice_df.price, w, b)

# %%
rmse(targets, predicted)
# Out:
# 1765361.9533874295

# %%
def try_parameters(w, b):
    enginesizes = CarPrice_df.enginesize
    target = CarPrice_df.price
    predictions = estimate_price(enginesizes, w, b)
    
    plt.plot(enginesizes, predictions, 'r', alpha=0.9);
    plt.scatter(enginesizes, target, s=8,alpha=0.8);
    plt.xlabel('EngineSize');
    plt.ylabel('Price')
    plt.legend(['Prediction', 'Actual']);
    
    loss = rmse(target, predictions)
    print("RMSE Loss: ", loss)

# %%
try_parameters(115, 100)
# Out:
# RMSE Loss:  4667.150588159285

# %% [markdown]
# Optimiser

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
help(model.fit)
# Out:
# Help on method fit in module sklearn.linear_model._base:
#
# fit(X, y, sample_weight=None) method of sklearn.linear_model._base.LinearRegression instance
#     Fit linear model.
#
#     Parameters
#     ----------
#     X : {array-like, sparse matrix} of shape (n_samples, n_features)
#         Training data.
#
#     y : array-like of shape (n_samples,) or (n_samples, n_targets)
#         Target values. Will be cast to X's dtype if necessary.
#
#     sample_weight : array-like of shape (n_samples,), default=None
#         Individual weights for each sample.
#
#         .. versionadded:: 0.17
#            parameter *sample_weight* support to LinearRegression.
#
#     Returns
#     -------
#     self : object
#         Fitted Estimator.

# %%
inputs = CarPrice_df[['enginesize']]
targets = CarPrice_df.price
print('inputs.shape :', inputs.shape)
print('targes.shape :', targets.shape)
# Out:
# inputs.shape : (205, 1)
# targes.shape : (205,)

# %%
model.fit(inputs, targets)
# Out:
# LinearRegression()

# %%
model.predict(np.array([[204], 
                        [8], 
                        [12]]))
# Out:
# /Users/krishnakumarjena/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([26205.03141306, -6663.8582    , -5993.06453443])

# %%
predictions = model.predict(inputs)

# %%
# w
model.coef_
# Out:
# array([167.69841639])

# %%
# b
model.intercept_
# Out:
# -8005.4455311452075

# %%
try_parameters(model.coef_, model.intercept_)
# Out:
# RMSE Loss:  3870.434265757697

# %% [markdown]
# Earlier by manually fitting the line, I had a RSME loss of 4667 and now after training the model, the RSME loss is 3870.
